# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjayGori/Adaptive-Time-Aware-PatchTST/blob/main/Supervised_Official.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/yuqinie98/patchtst.git
# %cd patchtst/PatchTST_supervised
# Out:
# Cloning into 'patchtst'...
# remote: Enumerating objects: 352, done.
# remote: Total 352 (delta 0), reused 0 (delta 0), pack-reused 352 (from 1)
# Receiving objects: 100% (352/352), 12.93 MiB | 13.30 MiB/s, done.
# Resolving deltas: 100% (154/154), done.
# /content/patchtst/PatchTST_supervised

# %%
# !pip install torch numpy pandas scikit-learn matplotlib einops yacs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !sed -i 's/np.Inf/np.inf/g' /content/patchtst/PatchTST_supervised/utils/tools.py

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-90c11852-f5c0-40fa-880a-1efc4cd24474" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90c11852-f5c0-40fa-880a-1efc4cd24474">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p dataset
# !mv AMZN.csv dataset/

# %%
import pandas as pd
df = pd.read_csv("dataset/AMZN.csv")
df = df.rename(columns={"Date": "date", "Adj Close": "OT"})
df.to_csv("dataset/AMZN.csv", index=False)

# %%
# !python run_longExp.py --is_training 1 --root_path ./dataset/ --data_path AMZN.csv \
--model_id PatchTST_AMZN --model PatchTST \
--data custom --features S --seq_len 96 --label_len 48 --pred_len 24 \
--patch_len 16 --stride 8 --des 'AMZN_test' --train_epochs 3 --batch_size 16
# Out:
# Args in experiment:
# Namespace(random_seed=2021, is_training=1, model_id='PatchTST_AMZN', model='PatchTST', data='custom', root_path='./dataset/', data_path='AMZN.csv', features='S', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=24, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.05, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=2, train_epochs=3, batch_size=16, patience=100, learning_rate=0.0001, des='AMZN_test', loss='mse', lradj='type3', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False)
# Use GPU: cuda:0
# ...

# %%
import numpy as np

pred = np.load('/content/patchtst/PatchTST_supervised/results/PatchTST_AMZN_PatchTST_custom_ftS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_AMZN_test_0/pred.npy')
true = np.load('/content/patchtst/PatchTST_supervised/results/PatchTST_AMZN_PatchTST_custom_ftS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_AMZN_test_1/pred.npy')

print("Sample Prediction:\n", pred[0])
print("Actual Values:\n", true[0])
# Out:
# Sample Prediction:
#  [[12.880997 ]
#  [12.95937  ]
#  [12.881528 ]
#  [12.7096815]
#  [12.80773  ]
#  [12.771835 ]
#  [12.818475 ]
#  [12.756649 ]
#  [12.862429 ]
#  [12.923025 ]
#  [12.870771 ]
#  [12.705376 ]
#  [12.944003 ]
#  [13.160624 ]
#  [12.816835 ]
#  [12.789054 ]
#  [13.142582 ]
#  [13.136897 ]
#  [13.139828 ]
#  [13.138672 ]
#  [13.085559 ]
#  [12.859757 ]
#  [13.013748 ]
#  [13.183674 ]]
# Actual Values:
#  [[12.561214]
#  [12.907337]
#  [12.761314]
#  [12.726784]
#  [12.645358]
#  [12.737746]
#  [12.812614]
#  [12.95554 ]
#  [12.824833]
#  [12.94242 ]
#  [12.850687]
#  [12.797895]
#  [13.022135]
#  [13.162824]
#  [13.354971]
#  [13.370665]
#  [13.46446 ]
#  [13.448575]
#  [13.488671]
#  [13.502246]
#  [13.563196]
#  [13.550928]
#  [13.714601]
#  [13.454102]]
